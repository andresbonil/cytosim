# %% [markdown]
# # Modifying cytosim objects
# Requires Python>=3.7
# Before running, copy or move the cytosim module (cytosim.---.so) to the current folder.
#
# Here we showcase by changing a fiber.

# %%
import cytosim
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_sim(sim):
    space = sim.spaces[0]
    plt.figure()
    r = np.linspace(0,2.0*np.pi,100)
    plt.plot(5.0* np.cos(r),5.0*np.sin(r),color="black")
    for fiber in sim.fibers:
        p = fiber.points()
        plt.plot(p[:,0],p[:,1])
        plt.scatter(p[:,0],p[:,1])
    

        
    plt.axis('equal')
    plt.show()

# %% [markdown]
# ## Fiber simulation
# Here we simulate and a fiber. Each point correspond to the end of a segment.

# %%
sim = cytosim.start("cym/fiber.cym")

# %%
plot_sim(sim)

# %%
sim.run(10)
plot_sim(sim)

# %% [markdown]
# ### Changing object properties
# Cythosim offers to ways to change a property : through directly accessing the property members, or by sending a change string.

# %%
fil_prop = sim.findProperty("filament")
print(f"Segmentation : {fil_prop.segmentation}")
# Out:
# Segmentation : 0.5

# %%
# Changing directly property members
fil_prop.segmentation = 2.0
fil_prop.complete(sim)
plot_sim(sim)

# %%
#Alternative : sending a change string
sim.change("filament","segmentation = 0.5")
plot_sim(sim)

# %% [markdown]
# ### Changing objects
# To know which functions are accessible to an object, use dir(object). To know what these functions do please refer to the cytosim documentation : these functions should mirror C++ functions.

# %%
print(dir(sim.fibers[0]))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'aboveM', 'abscissaC', 'abscissaEnd', 'abscissaFrom', 'abscissaM', 'abscissaP', 'abscissaPoint', 'addPoint', 'addSegmentM', 'addSegmentP', 'adjustLength', 'age', 'allInside', 'allocated', 'avgDirection', 'belowP', 'bendingEnergy0', 'betweenMP', 'birthTime', 'calculateMomentum', 'clampedIndexM', 'clearPoints', 'curvature', 'cutM', 'cutP', 'dragCoefficient', 'exactEnd', 'flipChainPolarity', 'freshAssembly', 'grow', 'growM', 'growP', 'id', 'interpolate', 'interpolateCenter', 'interpolateEnd', 'interpolateEndM', 'interpolateEndP', 'interpolateFromEnd', 'join', 'lastSegment', 'leftoverMobility', 'length', 'length1', 'nbHands', 'nbHandsInRange', 'nbPoints', 'nbSegments', 'netForce', 'netForceEndM', 'netForceEndP', 'next', 'nowSever', 'outsideMP', 'placeEnd', 'planarIntersect', 'points', 'pos', 'posEnd', 'posEndM', 'posEndP', 'posFrom', 'posM', 'posMiddle', 'posPoint', 'position', 'prev', 'projectedForceEndM', 'projectedForceEndP', 'property', 'reference', 'removePoints', 'segmentation', 'setDynamicState', 'setEquilibrated', 'setOrigin', 'setPoint', 'setStateM', 'setStateP', 'setStraight', 'setStraightLength', 'sever', 'severNow', 'severP', 'shiftPoints', 'someAbscissa', 'stateM', 'stateP', 'tension', 'translate', 'trueLength', 'truncateM', 'truncateP', 'whichEndDomain']

# %%
sim.fibers[0].growM(10)
plot_sim(sim)

# %%
sim.run(10)
plot_sim(sim)

# %%
sim.fibers[0].cutM(10)
plot_sim(sim)

# %% [markdown]
# ### Adding Objects

# %%
# Adding a single object
sim.add("filament")
plot_sim(sim)

# %%
# Adding with instructions
sim.add("filament","length = 10",)
plot_sim(sim)

# %%
# Adding several (3) objects
sim.add("filament","length = 3 ; orientation = 0 1;",3)
nf = len(sim.fibers)
print(f"Now {nf} fibers")
plot_sim(sim)
# Out:
# Now 6 fibers

# %% [markdown]
# ### Cutting

# %%
sim.cut("filament","plane = 0 1 0, 0")
nf = len(sim.fibers)
print(f"Now {nf} fibers")
plot_sim(sim)
# Out:
# Now 10 fibers

# %% [markdown]
# ### Severing Fibers

# %%
fibers = sim.fibers
frag = fibers[0].severP(1.0)
fibers.add(frag)
plot_sim(sim)

# %% [markdown]
# ### Deleting objects

# %%
sim.delete("filament","",3)
nf = len(sim.fibers)
print(f"Now {nf} fibers")
plot_sim(sim)
# Out:
# Now 8 fibers

# %%
sim.fibers.erase(sim.fibers[0])
plot_sim(sim)
